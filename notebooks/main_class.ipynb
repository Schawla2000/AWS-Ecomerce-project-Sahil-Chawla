# %% [markdown]
# Executing the Pipeline notebook

# %%
# %run /pipelines

# %% [markdown]
# Stating or Entry point if ETL process

# %%
BUCKET = "ecommerce-lake"

if __name__ == "__main__":
    BronzeToSilverETL(BUCKET).run()
    SilverToGoldETL(BUCKET).run()
